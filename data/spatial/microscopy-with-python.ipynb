# %%
from skimage import io
im = io.imread('C12500column.tif').reshape(145,3,3702,966)

# C12 =500; C6=2.5, 5, 10, 20, 40, 80, 160

# %%
from matplotlib.pyplot import *
from numpy import *

# %%
C12500C6160 = im[:,:,:500,:]
C12500C680 = im[:,:,500:1000,:]
C12500C640 = im[:,:,1000:1500,:]
C12500C620 = im[:,:,1500:2000,:]
C12500C610 = im[:,:,2000:2500,:]
C12500C65 = im[:,:,2800:3050,:]
C12500C625 = im[:,:,-250:,:]

# %%
moveaxis(C12500C620,0,-1).shape
# Out:
# (3, 500, 966, 145)

# %%
im[-1,:,:,:] = 0

# %%
moveaxis(im,0,-1).shape
# Out:
# (3, 3702, 966, 145)

# %%
figure(figsize=(18,18))

imshow(moveaxis(im,1,-1)[30])

# %%
from matplotlib.pyplot import *
from numpy import *

# %%
from numpy import histogram

# %%
imshow(all(im >100,axis=-1))

# %%
figure(figsize=(18,18))
imshow(im.reshape(5292,243,3))

# %%
imshow(im)

# %%
plot(mean(im.reshape(5292,243,3),axis=(1,-1)))

# %%
# ints
1,2,3,

# floats
1.23234, -1.2123, 1.0

# str
'sdfs','wewerwe'

# lists 
[1,'as',1.2], [None,None,None]

# dictionaries 
z = { 'a' : 1, 'b' : 2}

# %%
z = uniform(size=(2,3,4))
a = uniform(size=(2,3,4))

# %%
z[0,1
# Out:
# array([0.50557989, 0.12602808, 0.53453339, 0.35239283])

# %%
z.shape
# Out:
# (2, 3, 4)

# %%
x = arange(0,10)

# %%
x[1]
# Out:
# 1

# %%
y = [3.14159,'frsf',3,[1,2,3],5]

# %%
z = { 'a' : 1, 'b' : 2}

# %%
z['b']
# Out:
# 2

# %%
y[2:15]
# Out:
# [3, [1, 2, 3], 5]

# %%
y[start:end:step]
