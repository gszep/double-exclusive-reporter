# %%
from skimage import io
im = io.imread('C12500column.tif')

from matplotlib.pyplot import *

# %%
im.shape
# Out:
# (145, 3702, 966, 3)

# %%
figure(figsize=(15,15))
imshow(im[0])

# %%
from matplotlib.pyplot import *
from numpy import *

# %%
C12500C6160 = im[:,130:320,220:900,:]
C12500C680 = im[:,680:860,190:880,:]
C12500C640 = im[:,1210:1380,240:920,:]
C12500C620 = im[:,1760:1940,160:840,:]
C12500C610 = im[:,2290:2470,210:890,:]
C12500C65 = im[:,2830:3030,150:830,:]
C12500C625 = im[:,-230:-40,170:850,:]

# %%
figure(figsize=(18,18))

imshow(C12500C625[-1,...,2])

# %%
io.imsave('C12500C625.tif',C12500C625)

# %%
C12500C625.shape
# Out:
# (145, 190, 680, 3)

# %%
from matplotlib.pyplot import *
from numpy import *

# %%
from numpy import histogram

# %%
imshow(all(im >100,axis=-1))

# %%
figure(figsize=(18,18))
imshow(im.reshape(5292,243,3))

# %%
imshow(im)

# %%
plot(mean(im.reshape(5292,243,3),axis=(1,-1)))

# %%
# ints
1,2,3,

# floats
1.23234, -1.2123, 1.0

# str
'sdfs','wewerwe'

# lists 
[1,'as',1.2], [None,None,None]

# dictionaries 
z = { 'a' : 1, 'b' : 2}

# %%
z = uniform(size=(2,3,4))
a = uniform(size=(2,3,4))

# %%
z[0,1
# Out:
# array([0.50557989, 0.12602808, 0.53453339, 0.35239283])

# %%
z.shape
# Out:
# (2, 3, 4)

# %%
x = arange(0,10)

# %%
x[1]
# Out:
# 1

# %%
y = [3.14159,'frsf',3,[1,2,3],5]

# %%
z = { 'a' : 1, 'b' : 2}

# %%
z['b']
# Out:
# 2

# %%
y[2:15]
# Out:
# [3, [1, 2, 3], 5]

# %%
y[start:end:step]
